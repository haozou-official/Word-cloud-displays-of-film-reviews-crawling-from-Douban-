周的摩天大楼好看也就五倍吧不需要等上十年或二十年这部电影现在就是经典那个法国女警察在一分钟之内就会爱上阿汤哥吧太撩了单纯视觉上来说在棚拍人工布光和后期大行其道的近两年碟干净不矫揉造作的实景和直白的自然光在满屏画幅上真有洗眼睛之感啊动作戏超棒的能不能学学这个系列好好做个人吧最后半小时真是紧张到不敢大喘气因为这部给了阿汤官配被晾了不开心做过蜘蛛侠徒手攀爬过悬崖跳跃过上海摩天楼单手爬过迪拜塔站在飞行的军事飞机外这一次再来个高空跳伞绳爬直升机对撞然后再给大家重温一下骑摩托悬崖攀岩实拳格斗等等等等这样的阿汤哥即使岁依旧拼命怎能不爱阿汤哥演的伊森太完美了以至
# ...

# %%
f = open("1.txt", 'w+')
f.write(cleaned_comments)
f.close()

# %%
import jieba    
import pandas as pd  

segment = jieba.lcut(cleaned_comments)
words_df=pd.DataFrame({'segment':segment})
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /var/folders/14/j2kbqyps42d389c_2gy6y2980000gn/T/jieba.cache
# Loading model cost 1.081 seconds.
# Prefix dict has been built succesfully.

# %%
stopwords=pd.read_csv('/Users/zouhao/Desktop/chineseStopWords.txt',index_col=False,quoting=3,sep="\t",names=['stopword'], encoding='gb18030')#quoting=3全不引用
words_df=words_df[~words_df.segment.isin(stopwords.stopword)]
words_df.head()
# Out:
#   segment
# 0     阿汤哥
# 2     碟中谍
# 4      历史
# 6     第一个
# 8      镜头

# %%
import numpy
words_stat=words_df.groupby(by=['segment'])['segment'].agg({"计数":numpy.size})
words_stat=words_stat.reset_index().sort_values(by=["计数"],ascending=False)
words_stat.head()
# Out:
# /anaconda3/envs/python36/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#     segment  计数
# 411     阿汤哥  18
# 305      真的   9
# 379      跳伞   8
# 329      系列   6
# 10       一部   5

# %%
from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
 
import os
os.getcwd()
df = open(r"1.txt")

# %%
comment_words = ' '
stopwords = set(STOPWORDS)
 
for val in df:
    val = str(val)
    tokens = val.split()
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()        
    for words in tokens:
        comment_words = comment_words + words + ' '

# %%
plt.figure(figsize = (20, 20), facecolor = None)
plt.imshow(w)
plt.tight_layout(pad = 0)
 
plt.show()

# %%
import jieba
import wordcloud

f = open("1.txt", "r", encoding="utf-8") 

t = f.read()
f.close()
ls = jieba.lcut(t)

txt = " ".join(ls)
w = wordcloud.WordCloud(
    width=1000, height=700,
    background_color="white",
    font_path="/Users/zouhao/Desktop/msyh.TTF" 
)
w.generate(txt)

# %%
plt.figure(figsize = (20, 20), facecolor = None)
plt.imshow(w)
plt.tight_layout(pad = 0)
 
plt.show()

# %%
import jieba
import wordcloud
from scipy.misc import imread

mask = imread("/Users/zouhao/Desktop/碟中谍.p") 
excludes = { }

f = open("1.txt", "r", encoding="utf-8") 

t = f.read()
f.close()
ls = jieba.lcut(t)
txt = " ".join(ls)

w2 = wordcloud.WordCloud(
    width = 550, height = 500,
    background_color = "white",
    font_path = "/Users/zouhao/Desktop/msyh.TTF",
    mask = mask
)

w2.generate(txt)
# Out:
# /anaconda3/envs/python36/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """

# %%
plt.figure(figsize = (20, 20), facecolor = None)
plt.imshow(w2)
plt.tight_layout(pad = 0)
 
plt.show()
